# %%
pip install keras tensorflow
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (3.8.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras) (0.14.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras) (24.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)

# %%
import tensorflow as tf
print(tf.keras.__version__)
# Out:
# 3.8.0

# %%
import tensorflow as tf

x = tf.Variable(5.0)  # Trainable variable

with tf.GradientTape() as tape:
    fy = x ** 2  # y = x^2

grad = tape.gradient(fy, x)  # Computes dy/dx automatically
print(grad.numpy())  # Output: 10.0
# Out:
# 10.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)

# %%
# !unzip "/content/drive/MyDrive/AI and ML/week4/Copy of Copy of devnagari digit.zip" -d "/content/drive/MyDrive/AI and ML/week4"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/10299.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/10300.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/10301.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/10302.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/10303.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/10304.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/10306.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/10307.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104017.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104018.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104019.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104021.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104023.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104024.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104025.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104026.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104027.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104028.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104029.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104030.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104031.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104032.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104033.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104034.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104057.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104058.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104059.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104060.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104061.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104062.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104065.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104066.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104067.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104068.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104069.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104070.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104071.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104072.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104075.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104076.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104078.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104079.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104080.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104082.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104084.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104085.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104086.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104087.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104088.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104089.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104090.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104092.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104094.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104095.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104096.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104098.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104099.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/104101.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12706.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12707.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12709.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12711.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12712.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12713.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12714.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12715.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12716.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12718.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12720.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12721.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12723.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12724.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12725.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12726.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12727.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12728.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12730.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12731.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12732.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12733.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12734.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12735.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12736.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12737.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12738.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/12739.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13582.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13583.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13584.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13586.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13587.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13588.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13589.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13590.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13591.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13592.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13593.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13594.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13595.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13596.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13597.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13598.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13600.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/13601.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22874.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22875.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22876.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22877.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22878.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22879.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22880.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22881.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22882.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22883.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22884.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22885.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22886.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22887.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22888.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22889.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/22890.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30200.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30201.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30202.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30203.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30204.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30205.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30206.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30207.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30208.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30209.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30210.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30211.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30212.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30213.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30214.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30215.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30216.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30217.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30218.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30219.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30220.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30221.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30222.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30223.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30224.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30225.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30226.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30227.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30228.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30229.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30231.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30232.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30233.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30234.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30236.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30237.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30238.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30239.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30240.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30241.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30242.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30243.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30244.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30246.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30247.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30248.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30249.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30250.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30251.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30252.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30253.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30254.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30255.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30256.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30257.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30258.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30259.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30260.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30261.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30262.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30263.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30264.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30265.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30266.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30267.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30269.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30270.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30271.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30272.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30273.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30274.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30275.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30276.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30277.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30278.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30279.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30280.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30282.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30283.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30284.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30285.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30286.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30287.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30288.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30289.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30290.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30291.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30292.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30293.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30294.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30295.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30296.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30297.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30298.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30299.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30300.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30301.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30302.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30303.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30304.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30305.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30307.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30308.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30311.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30312.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30313.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30314.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30315.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30316.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30317.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30318.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30319.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30320.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30321.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30322.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30323.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30324.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30325.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30326.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30327.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30330.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30331.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30332.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30333.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30334.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30335.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30337.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30338.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30339.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30340.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30341.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30342.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30343.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30344.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30345.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30346.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30347.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30348.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30349.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30350.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30351.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30352.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30353.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30354.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30355.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30356.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30357.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30358.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30359.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30361.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30362.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30365.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30366.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30367.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30368.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30369.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30370.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30371.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30372.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30373.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30374.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30375.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30376.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30378.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30379.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30380.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30381.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30382.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30383.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30385.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30386.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30387.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30389.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30390.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30391.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30393.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30394.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30395.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30396.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30398.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30399.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30400.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30401.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30402.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30403.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30404.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30405.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30407.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30409.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30410.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30411.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30412.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30413.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30414.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30415.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30416.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30417.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30418.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30419.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30420.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30421.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30422.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30423.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30424.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30425.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30426.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30427.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30428.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30430.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30431.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30433.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30435.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30436.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30437.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30438.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30439.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30440.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30442.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30444.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30445.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30446.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30448.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30449.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30450.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30451.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30452.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30453.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30454.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30455.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30456.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30457.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30458.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30459.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30460.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30461.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30462.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30463.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30464.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30465.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30466.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30467.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30468.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30469.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30470.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/30472.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41776.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41777.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41778.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41779.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41780.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41781.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41782.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41784.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41786.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41788.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41789.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41790.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41791.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41792.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41793.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41794.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41795.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41796.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41797.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41798.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41799.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41800.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41801.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41802.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41803.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41804.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41806.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41807.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41808.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41809.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41810.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41812.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41814.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41815.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41816.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41817.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41818.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41819.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41820.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41821.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41822.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41823.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41824.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41825.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41826.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41827.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41828.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41829.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41830.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41831.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41834.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41835.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41837.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41839.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41840.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41841.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41842.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41843.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41844.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41845.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_7/41846.png
# ...
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99490.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99491.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99492.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99493.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99494.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99495.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99496.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99497.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99500.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99641.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99642.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99643.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99644.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99646.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99647.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99648.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99649.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99650.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99651.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99652.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99653.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99654.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99655.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99657.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99659.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99660.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99661.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99662.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99663.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99664.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99665.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99666.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99667.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99668.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99669.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99670.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99671.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99672.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99673.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99674.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99675.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99676.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99677.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99678.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99680.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99681.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99682.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99685.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99686.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99688.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99689.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99690.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99691.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99692.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99693.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99694.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99695.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99696.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99697.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99698.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99699.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99700.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99701.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99704.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99705.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99706.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99707.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99708.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99729.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99730.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99731.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99732.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99733.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99734.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99735.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99736.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99737.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99738.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99739.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99740.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99741.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99742.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99743.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99744.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99745.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99746.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99747.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99748.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99749.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99750.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99753.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99754.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99755.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99756.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99757.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99758.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99759.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99760.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99761.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99762.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99763.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99764.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99766.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99767.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99768.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99769.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99770.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99771.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99773.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99776.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99778.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99779.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99780.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99781.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99783.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99784.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99785.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99787.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99788.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99789.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99790.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99791.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99793.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99795.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99797.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99799.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99800.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99802.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99803.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99804.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99805.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99806.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99808.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99809.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99811.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99812.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99813.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99814.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99815.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99816.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99817.png
#   inflating: /content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_9/99818.png

# %%
# !ls "/content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Test"
# Out:
# digit_0  digit_1  digit_2  digit_3  digit_4  digit_5  digit_6  digit_7	digit_8  digit_9

# %%
# !ls "/content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train/digit_0"
# Out:
# 103265.png  12335.png  28867.png  39442.png  4575.png	49273.png  6783.png   76339.png  9506.png
# 103266.png  12336.png  28868.png  39443.png  4576.png	49274.png  6784.png   76340.png  9507.png
# 103267.png  12337.png  28870.png  39444.png  4577.png	49275.png  6785.png   76341.png  9508.png
# 103268.png  12338.png  28873.png  39446.png  4578.png	49277.png  6786.png   76342.png  9509.png
# 103269.png  12339.png  28874.png  39447.png  4579.png	49278.png  6787.png   76343.png  9510.png
# 103270.png  12340.png  28876.png  39448.png  4580.png	49279.png  6788.png   76344.png  9511.png
# 103271.png  12341.png  28877.png  39449.png  4581.png	49280.png  6789.png   76345.png  9512.png
# 103272.png  12342.png  28878.png  39450.png  4582.png	49281.png  6790.png   76346.png  9513.png
# 103273.png  12343.png  28879.png  39451.png  4583.png	49282.png  6791.png   76347.png  9514.png
# 103274.png  12344.png  28880.png  39452.png  4585.png	49283.png  6792.png   76348.png  9515.png
# 103275.png  12345.png  28882.png  39453.png  4586.png	49284.png  6793.png   76349.png  9516.png
# 103276.png  12347.png  28883.png  39454.png  4587.png	49285.png  6794.png   76350.png  9517.png
# 103279.png  12349.png  28885.png  39455.png  4588.png	49286.png  6795.png   76351.png  9518.png
# 103280.png  12351.png  28887.png  39456.png  4589.png	49287.png  6796.png   76352.png  9519.png
# 103282.png  12353.png  28888.png  39458.png  4590.png	49289.png  6797.png   76353.png  9520.png
# 103283.png  12354.png  28890.png  39459.png  4591.png	49290.png  6798.png   76354.png  9521.png
# 103284.png  12355.png  28891.png  39460.png  4592.png	49291.png  6799.png   76355.png  9522.png
# 103305.png  12356.png  28892.png  39462.png  4595.png	49292.png  6800.png   76356.png  9523.png
# 103306.png  12357.png  28893.png  39463.png  4596.png	49294.png  6801.png   76357.png  9524.png
# 103307.png  12359.png  28894.png  39464.png  4597.png	49295.png  6802.png   76359.png  9525.png
# 103308.png  12360.png  28895.png  39465.png  4598.png	49296.png  6803.png   76360.png  9526.png
# 103310.png  12361.png  28896.png  39466.png  4599.png	49297.png  6804.png   76361.png  9527.png
# 103312.png  12362.png  28897.png  39468.png  4601.png	49298.png  6806.png   76362.png  9528.png
# 103313.png  12363.png  28898.png  39469.png  4602.png	49299.png  6807.png   76363.png  9530.png
# 103314.png  12364.png  28899.png  39470.png  4603.png	49300.png  6808.png   76364.png  9532.png
# 103315.png  12365.png  28900.png  39472.png  4604.png	49301.png  6809.png   85645.png  9533.png
# 103316.png  12366.png  28901.png  39473.png  4605.png	49302.png  6810.png   85647.png  9534.png
# 103317.png  12367.png  28902.png  39475.png  4606.png	49304.png  6811.png   85648.png  9535.png
# 103318.png  12368.png  28904.png  39476.png  4607.png	49305.png  6812.png   85649.png  9536.png
# 103319.png  12369.png  28905.png  39477.png  4610.png	49306.png  6813.png   85650.png  9537.png
# 103320.png  12370.png  28906.png  39478.png  4611.png	49308.png  6814.png   85653.png  9538.png
# 103321.png  12371.png  28908.png  39479.png  4612.png	49309.png  6815.png   85654.png  9539.png
# 103323.png  12372.png  28910.png  39481.png  4613.png	49310.png  6816.png   85655.png  9540.png
# 103324.png  12373.png  28911.png  39482.png  4614.png	49311.png  6817.png   85660.png  9541.png
# 103326.png  12374.png  28912.png  39483.png  4615.png	49313.png  6818.png   85661.png  9542.png
# 103327.png  12375.png  28913.png  39485.png  4616.png	49314.png  6820.png   86467.png  9543.png
# 103328.png  12377.png  28914.png  39489.png  4618.png	49316.png  6821.png   86468.png  9544.png
# 103329.png  12378.png  28915.png  39490.png  4619.png	49317.png  6822.png   86469.png  9546.png
# 103330.png  12379.png  28916.png  39491.png  4620.png	49318.png  6825.png   86470.png  9547.png
# 103331.png  12380.png  28917.png  39492.png  4621.png	50780.png  6826.png   86471.png  9548.png
# 103332.png  12381.png  28918.png  39493.png  4622.png	50781.png  6827.png   86472.png  9549.png
# 103333.png  12382.png  28919.png  39494.png  4623.png	53033.png  6828.png   86473.png  9550.png
# 103334.png  12383.png  28920.png  39495.png  4624.png	53035.png  6829.png   86474.png  9551.png
# 103335.png  12384.png  28921.png  39496.png  4625.png	53036.png  6830.png   86475.png  9552.png
# 103336.png  12386.png  28923.png  39497.png  4626.png	53037.png  6831.png   86476.png  9554.png
# 103337.png  12387.png  28924.png  39498.png  4627.png	53039.png  69079.png  86477.png  9555.png
# 103338.png  12389.png  28925.png  39499.png  4628.png	53041.png  69080.png  86478.png  9556.png
# 103339.png  12390.png  28927.png  39500.png  4629.png	53043.png  69081.png  86479.png  9557.png
# 103341.png  12393.png  28928.png  39501.png  4630.png	53044.png  71205.png  86480.png  9558.png
# 103342.png  12394.png  28929.png  39502.png  4631.png	53045.png  76184.png  86481.png  9560.png
# 103344.png  12395.png  28930.png  39503.png  4632.png	53046.png  76185.png  89367.png  9561.png
# 103345.png  12396.png  28931.png  39504.png  4633.png	53048.png  76186.png  89369.png  9562.png
# 103346.png  13424.png  28932.png  39505.png  4634.png	53049.png  76188.png  89370.png  9563.png
# 103347.png  13425.png  28933.png  39509.png  4635.png	53050.png  76189.png  89371.png  9564.png
# 103348.png  13426.png  28935.png  39510.png  4638.png	53051.png  76190.png  89372.png  9565.png
# 103349.png  13427.png  28936.png  39511.png  4639.png	53052.png  76191.png  89373.png  9566.png
# 103350.png  13428.png  28937.png  39513.png  4640.png	53055.png  76192.png  89374.png  9568.png
# 103351.png  13429.png  28938.png  39514.png  4642.png	53058.png  76193.png  89375.png  9569.png
# 103352.png  13430.png  28939.png  39515.png  4643.png	53059.png  76194.png  89376.png  9570.png
# 103353.png  13431.png  28942.png  39516.png  4644.png	53060.png  76195.png  89377.png  9571.png
# 103354.png  13432.png  28944.png  39518.png  4646.png	53061.png  76196.png  89379.png  9572.png
# 103355.png  13433.png  28945.png  39519.png  4647.png	53063.png  76197.png  89380.png  9573.png
# 103356.png  13434.png  28946.png  39520.png  4648.png	66547.png  76198.png  89382.png  9574.png
# 103357.png  13435.png  28947.png  39521.png  4649.png	66548.png  76199.png  89384.png  9576.png
# 103359.png  13436.png  28948.png  39522.png  4650.png	66549.png  76200.png  89386.png  9578.png
# 103360.png  13437.png  28950.png  39523.png  4651.png	66550.png  76201.png  89387.png  9581.png
# 103361.png  13439.png  28951.png  39524.png  4652.png	66551.png  76202.png  89388.png  9583.png
# 103362.png  13440.png  28952.png  39525.png  4653.png	66552.png  76203.png  89389.png  9584.png
# 103363.png  13441.png  28953.png  39526.png  4654.png	66554.png  76204.png  89390.png  9585.png
# 103364.png  13442.png  28954.png  39527.png  4655.png	66555.png  76205.png  89391.png  9586.png
# 103365.png  13443.png  28955.png  39528.png  4656.png	66557.png  76206.png  89392.png  99501.png
# 103367.png  13444.png  28957.png  39530.png  4658.png	66559.png  76207.png  89393.png  99502.png
# 103368.png  18491.png  28958.png  39531.png  4659.png	66561.png  76208.png  89394.png  99504.png
# 103370.png  18492.png  39308.png  39532.png  4660.png	66562.png  76209.png  89395.png  99505.png
# 103371.png  18493.png  39309.png  39533.png  4661.png	66563.png  76210.png  89396.png  99506.png
# 103373.png  18496.png  39310.png  39534.png  4662.png	66564.png  76211.png  89397.png  99507.png
# 103374.png  18497.png  39311.png  39535.png  4663.png	66565.png  76213.png  89398.png  99508.png
# 103375.png  18498.png  39312.png  39536.png  4664.png	66566.png  76214.png  89399.png  99509.png
# 103376.png  18500.png  39313.png  39537.png  4666.png	66567.png  76215.png  89400.png  99510.png
# 103377.png  18501.png  39314.png  39539.png  4668.png	66568.png  76216.png  89401.png  99511.png
# 103378.png  18502.png  39315.png  39540.png  4669.png	66569.png  76217.png  89402.png  99512.png
# 103379.png  18503.png  39316.png  39541.png  4671.png	66570.png  76218.png  89403.png  99513.png
# 103381.png  18504.png  39317.png  39542.png  4672.png	66571.png  76219.png  89404.png  99515.png
# 103382.png  18505.png  39318.png  39543.png  4673.png	66572.png  76220.png  89405.png  99516.png
# 103383.png  18507.png  39320.png  39544.png  4674.png	66573.png  76221.png  89406.png  99517.png
# 103384.png  18508.png  39321.png  39545.png  4675.png	66575.png  76222.png  89407.png  99518.png
# 103385.png  18509.png  39322.png  39547.png  4676.png	66577.png  76223.png  89408.png  99519.png
# 103387.png  18510.png  39323.png  39548.png  4677.png	66578.png  76224.png  89409.png  99520.png
# 103388.png  18511.png  39324.png  39549.png  4679.png	66579.png  76225.png  89410.png  99521.png
# 103389.png  18512.png  39325.png  39550.png  4680.png	66580.png  76226.png  89411.png  99524.png
# 103390.png  18513.png  39326.png  39551.png  4681.png	66581.png  76227.png  89412.png  99525.png
# 103391.png  18514.png  39327.png  39552.png  4682.png	66582.png  76228.png  89413.png  99526.png
# 103392.png  18515.png  39329.png  39553.png  4683.png	66583.png  76229.png  89415.png  99527.png
# 103393.png  18516.png  39330.png  39555.png  4684.png	66585.png  76230.png  89416.png  99528.png
# 103394.png  18518.png  39331.png  39556.png  4685.png	66586.png  76231.png  89417.png  99529.png
# 103395.png  18519.png  39333.png  39557.png  4686.png	66588.png  76232.png  89419.png  99531.png
# 103397.png  18520.png  39334.png  39558.png  4687.png	66589.png  76233.png  89420.png  99532.png
# 103399.png  18521.png  39335.png  39559.png  4688.png	66590.png  76234.png  89421.png  99533.png
# 103400.png  18522.png  39336.png  39561.png  4690.png	66591.png  76236.png  89422.png  99534.png
# 103402.png  18523.png  39337.png  39563.png  4691.png	66592.png  76237.png  89424.png  99535.png
# 103403.png  18524.png  39338.png  39564.png  4692.png	66593.png  76238.png  89425.png  99537.png
# 103405.png  18525.png  39339.png  39565.png  4693.png	66594.png  76239.png  89426.png  99538.png
# 103406.png  18526.png  39340.png  39566.png  4694.png	66595.png  76240.png  89427.png  99539.png
# 103407.png  18527.png  39342.png  39567.png  4695.png	66596.png  76241.png  89428.png  99540.png
# 103408.png  18529.png  39343.png  39568.png  4696.png	66597.png  76242.png  89429.png  99541.png
# 103409.png  18530.png  39344.png  39569.png  4697.png	66599.png  76243.png  89430.png  99542.png
# 103410.png  18531.png  39345.png  39570.png  4699.png	66600.png  76244.png  89431.png  99543.png
# 103411.png  18533.png  39346.png  39571.png  4700.png	66601.png  76245.png  89432.png  99544.png
# 103412.png  18535.png  39347.png  39572.png  4702.png	66602.png  76246.png  89433.png  99545.png
# 103413.png  18536.png  39348.png  39573.png  4703.png	66603.png  76247.png  89435.png  99546.png
# 103415.png  18537.png  39349.png  39574.png  4704.png	66604.png  76248.png  89436.png  99547.png
# 103416.png  18538.png  39350.png  39575.png  4705.png	66605.png  76249.png  89438.png  99548.png
# 103417.png  18539.png  39351.png  39577.png  4706.png	66606.png  76250.png  89439.png  99549.png
# 103418.png  18540.png  39352.png  39578.png  4707.png	66607.png  76252.png  89440.png  99550.png
# 103419.png  18541.png  39353.png  39579.png  4708.png	66608.png  76253.png  89441.png  99551.png
# 103420.png  18543.png  39354.png  39580.png  4709.png	66609.png  76254.png  89442.png  99552.png
# 103422.png  18544.png  39355.png  39582.png  4710.png	66610.png  76256.png  89443.png  99553.png
# 103423.png  18545.png  39358.png  39583.png  4712.png	66611.png  76257.png  89444.png  99554.png
# 103426.png  18546.png  39359.png  39584.png  4713.png	66612.png  76258.png  89445.png  99556.png
# 103428.png  18548.png  39360.png  39585.png  4714.png	66613.png  76259.png  89447.png  99557.png
# 103429.png  18550.png  39361.png  39586.png  4717.png	66615.png  76260.png  89448.png  99558.png
# 103430.png  18551.png  39362.png  39587.png  4718.png	66616.png  76261.png  89449.png  99561.png
# 103431.png  18552.png  39363.png  39588.png  4719.png	66617.png  76262.png  89451.png  99563.png
# 103432.png  18553.png  39364.png  39589.png  4720.png	66618.png  76263.png  89453.png  99564.png
# 103433.png  18554.png  39365.png  39591.png  4721.png	66619.png  76264.png  89454.png  99565.png
# 103434.png  22751.png  39366.png  39593.png  4722.png	66620.png  76265.png  89455.png  99566.png
# 103435.png  22753.png  39367.png  39594.png  4724.png	66621.png  76266.png  89456.png  99570.png
# 103436.png  22754.png  39368.png  39595.png  4725.png	66622.png  76267.png  89457.png  99571.png
# 103437.png  22755.png  39369.png  39596.png  4726.png	66623.png  76268.png  89458.png  99572.png
# 103438.png  22756.png  39370.png  39597.png  4727.png	66624.png  76269.png  89459.png  99575.png
# 103440.png  22757.png  39371.png  39598.png  4728.png	66625.png  76270.png  89461.png  99576.png
# 103441.png  22758.png  39372.png  39599.png  4729.png	66626.png  76271.png  89462.png  99577.png
# 103442.png  22759.png  39373.png  39600.png  4730.png	66627.png  76272.png  89463.png  99578.png
# 12272.png   22761.png  39374.png  39601.png  4731.png	66628.png  76273.png  89464.png  99579.png
# 12273.png   22762.png  39375.png  39602.png  49211.png	66630.png  76274.png  89466.png  99580.png
# 12274.png   22764.png  39376.png  39603.png  49212.png	66631.png  76275.png  91463.png  99582.png
# 12275.png   28799.png  39377.png  43491.png  49213.png	66632.png  76276.png  91464.png  99583.png
# 12276.png   28800.png  39379.png  43492.png  49214.png	66633.png  76277.png  91465.png  99584.png
# 12277.png   28801.png  39380.png  43493.png  49216.png	66634.png  76278.png  91466.png  99585.png
# 12278.png   28802.png  39381.png  43495.png  49217.png	66635.png  76279.png  91467.png  99586.png
# 12279.png   28803.png  39382.png  43496.png  49218.png	66637.png  76280.png  91468.png  99587.png
# 12280.png   28804.png  39383.png  43497.png  49219.png	66638.png  76281.png  91469.png  99589.png
# 12281.png   28807.png  39384.png  43498.png  49220.png	66639.png  76282.png  91470.png  99590.png
# 12282.png   28808.png  39385.png  43499.png  49221.png	66640.png  76283.png  91471.png  99591.png
# 12283.png   28809.png  39386.png  43500.png  49223.png	66641.png  76284.png  91472.png  99592.png
# 12284.png   28810.png  39387.png  43502.png  49224.png	66642.png  76285.png  91473.png  99594.png
# 12285.png   28811.png  39389.png  43503.png  49225.png	66643.png  76286.png  91476.png  99595.png
# 12287.png   28812.png  39390.png  43504.png  49226.png	66645.png  76287.png  91477.png  99596.png
# 12288.png   28813.png  39391.png  43509.png  49227.png	66647.png  76288.png  91479.png  99597.png
# 12289.png   28814.png  39392.png  43510.png  49228.png	66650.png  76289.png  91480.png  99598.png
# 12290.png   28815.png  39393.png  43511.png  49230.png	66652.png  76290.png  91481.png  99599.png
# 12291.png   28816.png  39394.png  43513.png  49231.png	66653.png  76291.png  91483.png  99600.png
# 12292.png   28817.png  39396.png  43514.png  49232.png	66654.png  76292.png  91485.png  99601.png
# 12293.png   28819.png  39397.png  43515.png  49233.png	66655.png  76293.png  92385.png  99602.png
# 12295.png   28820.png  39398.png  43516.png  49234.png	66656.png  76294.png  92386.png  99603.png
# 12297.png   28821.png  39399.png  43518.png  49235.png	66657.png  76295.png  92387.png  99604.png
# 12298.png   28823.png  39400.png  43520.png  49236.png	66659.png  76296.png  92388.png  99605.png
# 12299.png   28825.png  39401.png  43521.png  49237.png	66660.png  76297.png  92389.png  99606.png
# 12300.png   28827.png  39403.png  43522.png  49238.png	66661.png  76298.png  92390.png  99607.png
# 12301.png   28828.png  39404.png  43523.png  49239.png	66662.png  76299.png  92391.png  99608.png
# 12302.png   28829.png  39405.png  43524.png  49240.png	66663.png  76301.png  92393.png  99609.png
# 12303.png   28830.png  39406.png  43525.png  49241.png	66664.png  76302.png  92394.png  99611.png
# 12304.png   28834.png  39407.png  43526.png  49242.png	66665.png  76304.png  92395.png  99612.png
# 12306.png   28835.png  39408.png  43527.png  49243.png	66666.png  76305.png  92396.png  99613.png
# 12307.png   28836.png  39409.png  43528.png  49244.png	66667.png  76306.png  92397.png  99614.png
# 12308.png   28839.png  39410.png  43529.png  49245.png	66669.png  76307.png  92398.png  99615.png
# 12309.png   28840.png  39411.png  44561.png  49246.png	66671.png  76308.png  92399.png  99616.png
# 12310.png   28841.png  39414.png  44562.png  49247.png	66674.png  76310.png  92400.png  99617.png
# 12311.png   28842.png  39416.png  44563.png  49248.png	66675.png  76311.png  92401.png  99618.png
# 12312.png   28844.png  39417.png  44564.png  49249.png	66676.png  76313.png  92402.png  99619.png
# 12315.png   28845.png  39418.png  44565.png  49250.png	66677.png  76314.png  92403.png  99620.png
# 12316.png   28846.png  39419.png  44566.png  49251.png	66678.png  76316.png  92404.png  99621.png
# 12317.png   28847.png  39421.png  44567.png  49253.png	66679.png  76317.png  92405.png  99622.png
# 12318.png   28848.png  39422.png  4558.png   49254.png	66680.png  76318.png  92406.png  99623.png
# 12319.png   28849.png  39423.png  4559.png   49255.png	66681.png  76320.png  92407.png  99624.png
# 12320.png   28850.png  39424.png  4560.png   49256.png	6768.png   76321.png  92408.png  99626.png
# 12321.png   28851.png  39425.png  4561.png   49257.png	6769.png   76322.png  9488.png	 99627.png
# 12322.png   28854.png  39426.png  4562.png   49258.png	6770.png   76323.png  9489.png	 99628.png
# 12323.png   28855.png  39427.png  4563.png   49259.png	6771.png   76324.png  9490.png	 99629.png
# 12324.png   28856.png  39429.png  4564.png   49260.png	6772.png   76325.png  9491.png	 99630.png
# 12325.png   28857.png  39431.png  4565.png   49261.png	6773.png   76326.png  9492.png	 99631.png
# 12326.png   28859.png  39432.png  4566.png   49262.png	6774.png   76327.png  9494.png	 99632.png
# 12327.png   28860.png  39433.png  4567.png   49263.png	6775.png   76328.png  9495.png	 99633.png
# 12328.png   28861.png  39434.png  4568.png   49264.png	6776.png   76330.png  9496.png	 99634.png
# 12329.png   28862.png  39436.png  4569.png   49266.png	6777.png   76331.png  9497.png	 99635.png
# 12330.png   28863.png  39437.png  4570.png   49268.png	6778.png   76334.png  9498.png	 99636.png
# 12331.png   28864.png  39439.png  4571.png   49269.png	6779.png   76335.png  9501.png	 99637.png
# 12332.png   28865.png  39440.png  4572.png   49270.png	6780.png   76336.png  9504.png	 99639.png
# 12334.png   28866.png  39441.png  4573.png   49272.png	6782.png   76338.png  9505.png

# %%
from PIL import Image
import os
import numpy as np

# Path to the dataset folder
dataset_path = "/content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train"

# Placeholder for images and labels
images = []
labels = []

# Iterate through each folder and file
for label_folder in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, label_folder)
    if os.path.isdir(folder_path):  # Ensure it’s a directory
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            if file_name.endswith('.png'):  # Assuming images are PNG files
                # Open and process image
                image = Image.open(file_path).convert('L')  # Convert to grayscale
                image_array = np.array(image)  # Convert to numpy array
                images.append(image_array)
                labels.append(label_folder)  # Use folder name as label

# Convert lists to numpy arrays
images = np.array(images)
labels = np.array(labels)

print(f"Loaded {len(images)} images with labels.")
# Out:
# Loaded 17000 images with labels.

# %%
from PIL import Image
import os
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle

# Function to load, process, and normalize images
def load_images_and_labels(folder_path, target_size=(28, 28)):
    images = []
    labels = []
    label_mapping = {}  # To map folder names to numerical labels
    current_label = 0

    # Iterate through folders (each folder represents a class)
    for label_folder in sorted(os.listdir(folder_path)):  # Ensure consistent label order
        label_path = os.path.join(folder_path, label_folder)
        if os.path.isdir(label_path):
            # Map folder name to a numerical label
            if label_folder not in label_mapping:
                label_mapping[label_folder] = current_label
                current_label += 1

            for file_name in os.listdir(label_path):
                file_path = os.path.join(label_path, file_name)
                if file_name.endswith('.png'):  # Check for PNG files
                    # Load image, resize to target size, and convert to grayscale
                    image = Image.open(file_path).convert('L').resize(target_size)
                    image_array = np.array(image, dtype=np.float32)  # Convert to NumPy array
                    image_array /= 255.0  # Normalize to range 0-1
                    images.append(image_array)
                    labels.append(label_mapping[label_folder])  # Assign numerical label

    # Convert to NumPy arrays
    images = np.array(images)
    labels = np.array(labels)

    return images, labels, label_mapping

# Paths to the train and test folders
train_folder = "/content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Train"
test_folder = "/content/drive/MyDrive/AI and ML/week4/DevanagariHandwrittenDigitDataset/Test"

# Load and process training and testing data
train_images, train_labels, label_mapping = load_images_and_labels(train_folder)
test_images, test_labels, _ = load_images_and_labels(test_folder)

# ✅ Shuffle after loading!
train_images, train_labels = shuffle(train_images, train_labels, random_state=42)

# One-hot encode the labels for multi-class classification
train_labels = to_categorical(train_labels, num_classes=len(label_mapping))
test_labels = to_categorical(test_labels, num_classes=len(label_mapping))

# Confirm everything looks good
print(f"Training set: {train_images.shape[0]} images, {train_labels.shape[0]} labels.")
print(f"Testing set: {test_images.shape[0]} images, {test_labels.shape[0]} labels.")
print(f"Label Mapping: {label_mapping}")
print(os.listdir(train_folder))
# Out:
# Training set: 17000 images, 17000 labels.
# Testing set: 3000 images, 3000 labels.
# Label Mapping: {'digit_0': 0, 'digit_1': 1, 'digit_2': 2, 'digit_3': 3, 'digit_4': 4, 'digit_5': 5, 'digit_6': 6, 'digit_7': 7, 'digit_8': 8, 'digit_9': 9}
# ['digit_0', 'digit_1', 'digit_2', 'digit_3', 'digit_4', 'digit_5', 'digit_6', 'digit_7', 'digit_8', 'digit_9']

# %% [markdown]
# Task 2: Build the FCN Model
# Model Architecture
# • Create a Sequential model using Keras.
# • Add 3 hidden layers with the following number of neurons:
#
# – 1st hidden layer: 64 neurons
#
# – 2nd hidden layer: 128 neurons
#
# – 3rd hidden layer: 256 neurons
#
# • Use sigmoid activation functions for all hidden layers.
#
# • Add an output layer with 10 units with softmax (since Devnagari digits have 10 classes) and a
# softmax activation function.

# %%
from tensorflow.keras.models import Sequential

# Initialize the Sequential model
model = Sequential()

print("Sequential model initialized.")
# Out:
# Sequential model initialized.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense  # Import necessary layers

model = Sequential()
model.add(Flatten(input_shape=(28, 28)))  # Flatten the input
model.add(Dense(64, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))  # Output layer for classification

model.summary()  # Print model architecture
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Task 3: Compile the Model
#
# Model Compilation
#
# • Choose an appropriate optimizer (e.g., Adam), loss function (e.g., sparse categorical crossentropy),
# and evaluation metric (e.g., accuracy).

# %%
from tensorflow.keras.optimizers import Adam

# Compile the previously built model
model.compile(optimizer=Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])


print("Model compiled successfully.")
# Out:
# Model compiled successfully.

# %%
print(f"Shape of train_images: {train_images.shape}")
print(f"Shape of train_labels: {train_labels.shape}")
# Out:
# Shape of train_images: (17000, 28, 28)
# Shape of train_labels: (17000, 10)

# %% [markdown]
# Task 4: Train the Model
#
# Model Training
#
# • Use the model.fit() function to train the model. Set the batch size to 128 and the number of
# epochs to 20.
#
# • Use validation split (validation split=0.2) to monitor the model’s performance on validation
# data.
#
# • Optionally, use callbacks such as ModelCheckpoint and EarlyStopping for saving the best model and avoiding overfitting.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Set up callbacks
checkpoint = ModelCheckpoint("best_model.h5", monitor="val_loss", save_best_only=True)
early_stopping = EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)
callbacks = [checkpoint, early_stopping]

# Define the model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(64, activation='relu'),
    Dense(128, activation='relu'),
    Dense(256, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model before training
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Assuming train_images and train_labels are already defined
history = model.fit(
    train_images, train_labels,
    batch_size=128,
    epochs=20,
    validation_split=0.2,
    callbacks=callbacks  # Use the callbacks list here
)

# Print model summary
print(model.summary())
# Out:
# Epoch 1/20
# 105/107 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6763 - loss: 1.0685
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6806 - loss: 1.0544 - val_accuracy: 0.9297 - val_loss: 0.2134
# Epoch 2/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9506 - loss: 0.1662
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9507 - loss: 0.1661 - val_accuracy: 0.9538 - val_loss: 0.1481
# Epoch 3/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9645 - loss: 0.1179
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9645 - loss: 0.1178 - val_accuracy: 0.9671 - val_loss: 0.1022
# Epoch 4/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9803 - loss: 0.0726 - val_accuracy: 0.9721 - val_loss: 0.1039
# Epoch 5/20
# 106/107 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9845 - loss: 0.0596
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9845 - loss: 0.0595 - val_accuracy: 0.9700 - val_loss: 0.0891
# Epoch 6/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9856 - loss: 0.0465
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9856 - loss: 0.0465 - val_accuracy: 0.9750 - val_loss: 0.0797
# Epoch 7/20
# 106/107 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9912 - loss: 0.0334
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9912 - loss: 0.0333 - val_accuracy: 0.9791 - val_loss: 0.0728
# Epoch 8/20
# 103/107 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9926 - loss: 0.0276
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9926 - loss: 0.0275 - val_accuracy: 0.9815 - val_loss: 0.0638
# Epoch 9/20
# 101/107 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9982 - loss: 0.0124
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9981 - loss: 0.0126 - val_accuracy: 0.9829 - val_loss: 0.0593
# Epoch 10/20
# 104/107 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0194
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9948 - loss: 0.0193 - val_accuracy: 0.9818 - val_loss: 0.0537
# Epoch 11/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9987 - loss: 0.0080 - val_accuracy: 0.9815 - val_loss: 0.0633
# Epoch 12/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9983 - loss: 0.0083 - val_accuracy: 0.9806 - val_loss: 0.0691
# Epoch 13/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9978 - loss: 0.0076 - val_accuracy: 0.9794 - val_loss: 0.0676
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_6 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 282,464 (1.08 MB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 188,310 (735.59 KB)
# None

# %%
test_loss, test_acc = model.evaluate(train_images, train_labels, verbose=2)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 532/532 - 1s - 2ms/step - accuracy: 0.9943 - loss: 0.0228
# Test accuracy: 0.9943

# %%
# Save model as .h5 file
model.save("devanagari_model.h5")
print("Model saved as devanagari_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as devanagari_model.h5

# %%
from tensorflow.keras.models import load_model

# Load the .h5 model
model = load_model("devanagari_model.h5")
print("Model loaded from devanagari_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded from devanagari_model.h5

# %%
# Use the model to make predictions on the test set
predictions = model.predict(train_images)

# Convert predictions from probabilities to digit labels
predicted_labels = np.argmax(predictions, axis=1)

# Check the first prediction
print(f"Predicted label for first image: {predicted_labels[0]}")
print(f"True label for first image: {np.argmax(train_labels[0])}")
# Out:
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Predicted label for first image: 6
# True label for first image: 6

# %%
import matplotlib.pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']

train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss', color='blue')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_acc) + 1), train_acc, label='Training Accuracy', color='blue')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.tight_layout()
plt.show()
